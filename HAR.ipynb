# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("train.csv")

# %%
data.head()
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1       0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2       0.279653      -0.019467      -0.113462     -0.995380     -0.967187
# 3       0.279174      -0.026201      -0.123283     -0.996091     -0.983403
# 4       0.276629      -0.016570      -0.115362     -0.998139     -0.980817
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.913526     -0.995112     -0.983185     -0.923527     -0.934724  ...
# 1     -0.960322     -0.998807     -0.974914     -0.957686     -0.943068  ...
# 2     -0.978944     -0.996520     -0.963668     -0.977469     -0.938692  ...
# 3     -0.990675     -0.997099     -0.982750     -0.989302     -0.938692  ...
# 4     -0.990482     -0.998321     -0.979672     -0.990441     -0.942469  ...
#
#    angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0                 -0.112754                          0.030400
# 1                  0.053477                         -0.007435
# 2                 -0.118559                          0.177899
# 3                 -0.036788                         -0.012892
# 4                  0.123320                          0.122542
#
#    angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                      -0.464761                          -0.018446
# 1                      -0.732626                           0.703511
# 2                       0.100699                           0.808529
# 3                       0.640011                          -0.485366
# 4                       0.693578                          -0.615971
#
#    angleXgravityMean  angleYgravityMean  angleZgravityMean  subject  Activity  \
# 0          -0.841247           0.179941          -0.058627        1         5
# 1          -0.844788           0.180289          -0.054317        1         5
# 2          -0.848933           0.180637          -0.049118        1         5
# 3          -0.848649           0.181935          -0.047663        1         5
# 4          -0.847865           0.185151          -0.043892        1         5
#
#    ActivityName
# 0      STANDING
# 1      STANDING
# 2      STANDING
# 3      STANDING
# 4      STANDING
#
# [5 rows x 564 columns]

# %%
data.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %%
data.ActivityName.unique()
# Out:
# array(['STANDING', 'SITTING', 'LAYING', 'WALKING', 'WALKING_DOWNSTAIRS',
#        'WALKING_UPSTAIRS'], dtype=object)

# %%
data= data.drop('subject',axis =1)

# %%
data.shape
# Out:
# (7352, 563)

# %%
#Obtain Train Data
X_train = pd.read_csv("train.csv")

# %%
#Obtain Test Data
X_test= pd.read_csv("test.csv")

# %%
y_test= X_test["Activity"]

# %%
test = X_test

# %%
test['Activity'] = y_test

# %%
test.shape
# Out:
# (2947, 564)

# %%
train = X_train
y_train = train.ActivityName
# train['Activity'] = y_train

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# ### Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ### Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ### Check for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', height=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# C:\Users\gssp4\anaconda3\envs\myenv2\lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\gssp4\anaconda3\envs\myenv2\lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\gssp4\anaconda3\envs\myenv2\lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\gssp4\anaconda3\envs\myenv2\lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\gssp4\anaconda3\envs\myenv2\lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\gssp4\anaconda3\envs\myenv2\lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()
# Out:
# C:\Users\gssp4\AppData\Local\Temp\ipykernel_17844\246852771.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
# C:\Users\gssp4\AppData\Local\Temp\ipykernel_17844\246852771.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
# C:\Users\gssp4\AppData\Local\Temp\ipykernel_17844\246852771.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
# C:\Users\gssp4\AppData\Local\Temp\ipykernel_17844\246852771.py:20: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
# C:\Users\gssp4\AppData\Local\Temp\ipykernel_17844\246852771.py:21: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
# C:\Users\gssp4\AppData\Local\Temp\ipykernel_17844\246852771.py:22: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')

# %% [markdown]
# ### Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# ## Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, height=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.043s...
# [t-SNE] Computed neighbors for 7352 samples in 1.933s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.597464
# [t-SNE] Computed conditional probabilities in 0.054s
# [t-SNE] Iteration 50: error = 119.3513794, gradient norm = 0.0415311 (50 iterations in 4.787s)
# [t-SNE] Iteration 100: error = 105.0441895, gradient norm = 0.0235816 (50 iterations in 2.804s)
# [t-SNE] Iteration 150: error = 99.7860718, gradient norm = 0.0172965 (50 iterations in 2.953s)
# [t-SNE] Iteration 200: error = 96.7995300, gradient norm = 0.0139444 (50 iterations in 2.393s)
# [t-SNE] Iteration 250: error = 94.6907501, gradient norm = 0.0115892 (50 iterations in 2.816s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 94.690750
# [t-SNE] Iteration 300: error = 4.2703052, gradient norm = 0.0181609 (50 iterations in 2.466s)
# [t-SNE] Iteration 350: error = 3.3598869, gradient norm = 0.0195292 (50 iterations in 2.181s)
# [t-SNE] Iteration 400: error = 2.8638518, gradient norm = 0.0155573 (50 iterations in 2.418s)
# [t-SNE] Iteration 450: error = 2.5706601, gradient norm = 0.0132951 (50 iterations in 2.582s)
# [t-SNE] Iteration 500: error = 2.3697045, gradient norm = 0.0113029 (50 iterations in 1.953s)
# [t-SNE] Iteration 550: error = 2.2210174, gradient norm = 0.0101563 (50 iterations in 2.219s)
# [t-SNE] Iteration 600: error = 2.1047475, gradient norm = 0.0091680 (50 iterations in 2.243s)
# [t-SNE] Iteration 650: error = 2.0097520, gradient norm = 0.0085598 (50 iterations in 2.159s)
# [t-SNE] Iteration 700: error = 1.9302483, gradient norm = 0.0079727 (50 iterations in 2.288s)
# [t-SNE] Iteration 750: error = 1.8626482, gradient norm = 0.0073390 (50 iterations in 2.731s)
# [t-SNE] Iteration 800: error = 1.8036432, gradient norm = 0.0069672 (50 iterations in 2.977s)
# [t-SNE] Iteration 850: error = 1.7517327, gradient norm = 0.0066723 (50 iterations in 2.507s)
# [t-SNE] Iteration 900: error = 1.7056615, gradient norm = 0.0063987 (50 iterations in 2.355s)
# [t-SNE] Iteration 950: error = 1.6641314, gradient norm = 0.0061597 (50 iterations in 2.682s)
# [t-SNE] Iteration 1000: error = 1.6268685, gradient norm = 0.0058357 (50 iterations in 2.739s)
# [t-SNE] KL divergence after 1000 iterations: 1.626868
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.031s...
# [t-SNE] Computed neighbors for 7352 samples in 1.149s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961446
# [t-SNE] Computed conditional probabilities in 0.098s
# [t-SNE] Iteration 50: error = 107.1654053, gradient norm = 0.0382404 (50 iterations in 4.210s)
# [t-SNE] Iteration 100: error = 95.6829681, gradient norm = 0.0142547 (50 iterations in 2.380s)
# [t-SNE] Iteration 150: error = 92.4067230, gradient norm = 0.0094759 (50 iterations in 2.608s)
# [t-SNE] Iteration 200: error = 90.7251663, gradient norm = 0.0071792 (50 iterations in 2.746s)
# [t-SNE] Iteration 250: error = 89.6937561, gradient norm = 0.0051919 (50 iterations in 2.410s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.693756
# [t-SNE] Iteration 300: error = 3.7111712, gradient norm = 0.0166999 (50 iterations in 2.727s)
# [t-SNE] Iteration 350: error = 2.9566505, gradient norm = 0.0166605 (50 iterations in 2.193s)
# [t-SNE] Iteration 400: error = 2.5390501, gradient norm = 0.0158411 (50 iterations in 2.118s)
# [t-SNE] Iteration 450: error = 2.2881548, gradient norm = 0.0133383 (50 iterations in 2.166s)
# [t-SNE] Iteration 500: error = 2.1240087, gradient norm = 0.0117677 (50 iterations in 2.006s)
# [t-SNE] Iteration 550: error = 2.0062580, gradient norm = 0.0104236 (50 iterations in 2.169s)
# [t-SNE] Iteration 600: error = 1.9166943, gradient norm = 0.0094806 (50 iterations in 2.043s)
# [t-SNE] Iteration 650: error = 1.8455422, gradient norm = 0.0087349 (50 iterations in 2.493s)
# [t-SNE] Iteration 700: error = 1.7873139, gradient norm = 0.0080712 (50 iterations in 2.162s)
# [t-SNE] Iteration 750: error = 1.7386012, gradient norm = 0.0075302 (50 iterations in 1.920s)
# [t-SNE] Iteration 800: error = 1.6969934, gradient norm = 0.0069344 (50 iterations in 2.414s)
# [t-SNE] Iteration 850: error = 1.6608419, gradient norm = 0.0067361 (50 iterations in 1.830s)
# [t-SNE] Iteration 900: error = 1.6292248, gradient norm = 0.0063376 (50 iterations in 1.945s)
# [t-SNE] Iteration 950: error = 1.6013292, gradient norm = 0.0060490 (50 iterations in 2.035s)
# [t-SNE] Iteration 1000: error = 1.5764576, gradient norm = 0.0057462 (50 iterations in 2.433s)
# [t-SNE] KL divergence after 1000 iterations: 1.576458
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.034s...
# [t-SNE] Computed neighbors for 7352 samples in 1.187s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133827
# [t-SNE] Computed conditional probabilities in 0.180s
# [t-SNE] Iteration 50: error = 97.9012604, gradient norm = 0.0340987 (50 iterations in 4.404s)
# [t-SNE] Iteration 100: error = 88.9314499, gradient norm = 0.0107376 (50 iterations in 2.558s)
# [t-SNE] Iteration 150: error = 86.7439651, gradient norm = 0.0057777 (50 iterations in 2.450s)
# [t-SNE] Iteration 200: error = 85.7368622, gradient norm = 0.0043763 (50 iterations in 2.982s)
# [t-SNE] Iteration 250: error = 85.1446381, gradient norm = 0.0034319 (50 iterations in 2.397s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.144638
# [t-SNE] Iteration 300: error = 3.2544208, gradient norm = 0.0156796 (50 iterations in 2.209s)
# [t-SNE] Iteration 350: error = 2.6055222, gradient norm = 0.0150084 (50 iterations in 2.279s)
# [t-SNE] Iteration 400: error = 2.2684426, gradient norm = 0.0140158 (50 iterations in 2.441s)
# [t-SNE] Iteration 450: error = 2.0605044, gradient norm = 0.0130328 (50 iterations in 2.630s)
# [t-SNE] Iteration 500: error = 1.9228015, gradient norm = 0.0116112 (50 iterations in 2.324s)
# [t-SNE] Iteration 550: error = 1.8270141, gradient norm = 0.0103589 (50 iterations in 2.927s)
# [t-SNE] Iteration 600: error = 1.7558517, gradient norm = 0.0093169 (50 iterations in 2.304s)
# [t-SNE] Iteration 650: error = 1.7007301, gradient norm = 0.0086296 (50 iterations in 2.480s)
# [t-SNE] Iteration 700: error = 1.6565067, gradient norm = 0.0078208 (50 iterations in 2.485s)
# [t-SNE] Iteration 750: error = 1.6203080, gradient norm = 0.0073759 (50 iterations in 2.641s)
# [t-SNE] Iteration 800: error = 1.5899169, gradient norm = 0.0067790 (50 iterations in 2.768s)
# [t-SNE] Iteration 850: error = 1.5640957, gradient norm = 0.0063344 (50 iterations in 2.746s)
# [t-SNE] Iteration 900: error = 1.5422472, gradient norm = 0.0058866 (50 iterations in 1.923s)
# [t-SNE] Iteration 950: error = 1.5232131, gradient norm = 0.0055488 (50 iterations in 1.999s)
# [t-SNE] Iteration 1000: error = 1.5067066, gradient norm = 0.0052095 (50 iterations in 1.882s)
# [t-SNE] KL divergence after 1000 iterations: 1.506707
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.027s...
# [t-SNE] Computed neighbors for 7352 samples in 0.866s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274336
# [t-SNE] Computed conditional probabilities in 0.213s
# [t-SNE] Iteration 50: error = 89.2991562, gradient norm = 0.0294953 (50 iterations in 3.817s)
# [t-SNE] Iteration 100: error = 82.9583130, gradient norm = 0.0079593 (50 iterations in 3.950s)
# [t-SNE] Iteration 150: error = 81.5896912, gradient norm = 0.0047793 (50 iterations in 2.718s)
# [t-SNE] Iteration 200: error = 81.0242767, gradient norm = 0.0031753 (50 iterations in 2.656s)
# [t-SNE] Iteration 250: error = 80.6957016, gradient norm = 0.0028350 (50 iterations in 2.816s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.695702
# [t-SNE] Iteration 300: error = 2.8000731, gradient norm = 0.0146628 (50 iterations in 2.490s)
# [t-SNE] Iteration 350: error = 2.2538331, gradient norm = 0.0134019 (50 iterations in 2.270s)
# [t-SNE] Iteration 400: error = 1.9889644, gradient norm = 0.0122166 (50 iterations in 2.726s)
# [t-SNE] Iteration 450: error = 1.8311992, gradient norm = 0.0112981 (50 iterations in 2.102s)
# [t-SNE] Iteration 500: error = 1.7253166, gradient norm = 0.0105346 (50 iterations in 1.933s)
# [t-SNE] Iteration 550: error = 1.6500320, gradient norm = 0.0097155 (50 iterations in 1.979s)
# [t-SNE] Iteration 600: error = 1.5951905, gradient norm = 0.0088545 (50 iterations in 1.803s)
# [t-SNE] Iteration 650: error = 1.5539081, gradient norm = 0.0080259 (50 iterations in 1.926s)
# [t-SNE] Iteration 700: error = 1.5215749, gradient norm = 0.0074156 (50 iterations in 1.894s)
# [t-SNE] Iteration 750: error = 1.4957346, gradient norm = 0.0066816 (50 iterations in 1.976s)
# [t-SNE] Iteration 800: error = 1.4747298, gradient norm = 0.0062678 (50 iterations in 2.500s)
# [t-SNE] Iteration 850: error = 1.4572489, gradient norm = 0.0055470 (50 iterations in 2.107s)
# [t-SNE] Iteration 900: error = 1.4431561, gradient norm = 0.0049439 (50 iterations in 1.978s)
# [t-SNE] Iteration 950: error = 1.4314517, gradient norm = 0.0046043 (50 iterations in 2.076s)
# [t-SNE] Iteration 1000: error = 1.4217024, gradient norm = 0.0041190 (50 iterations in 1.921s)
# [t-SNE] KL divergence after 1000 iterations: 1.421702
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.023s...
# [t-SNE] Computed neighbors for 7352 samples in 0.869s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.497s
# [t-SNE] Iteration 50: error = 78.8778381, gradient norm = 0.0243299 (50 iterations in 5.705s)
# [t-SNE] Iteration 100: error = 75.2916565, gradient norm = 0.0053407 (50 iterations in 3.638s)
# [t-SNE] Iteration 150: error = 74.5531464, gradient norm = 0.0032197 (50 iterations in 3.639s)
# [t-SNE] Iteration 200: error = 74.2547684, gradient norm = 0.0022905 (50 iterations in 3.846s)
# [t-SNE] Iteration 250: error = 74.0922928, gradient norm = 0.0017836 (50 iterations in 4.173s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.092293
# [t-SNE] Iteration 300: error = 2.2386341, gradient norm = 0.0130003 (50 iterations in 4.093s)
# [t-SNE] Iteration 350: error = 1.8232105, gradient norm = 0.0111804 (50 iterations in 4.017s)
# [t-SNE] Iteration 400: error = 1.6397549, gradient norm = 0.0098016 (50 iterations in 3.766s)
# [t-SNE] Iteration 450: error = 1.5368729, gradient norm = 0.0088421 (50 iterations in 4.272s)
# [t-SNE] Iteration 500: error = 1.4705498, gradient norm = 0.0081893 (50 iterations in 3.654s)
# [t-SNE] Iteration 550: error = 1.4242254, gradient norm = 0.0075676 (50 iterations in 3.553s)
# [t-SNE] Iteration 600: error = 1.3901455, gradient norm = 0.0071294 (50 iterations in 3.558s)
# [t-SNE] Iteration 650: error = 1.3645691, gradient norm = 0.0065018 (50 iterations in 3.743s)
# [t-SNE] Iteration 700: error = 1.3449986, gradient norm = 0.0059194 (50 iterations in 2.943s)
# [t-SNE] Iteration 750: error = 1.3301587, gradient norm = 0.0052971 (50 iterations in 2.807s)
# [t-SNE] Iteration 800: error = 1.3188810, gradient norm = 0.0045103 (50 iterations in 2.727s)
# [t-SNE] Iteration 850: error = 1.3104166, gradient norm = 0.0037223 (50 iterations in 2.655s)
# [t-SNE] Iteration 900: error = 1.3040385, gradient norm = 0.0032335 (50 iterations in 2.492s)
# [t-SNE] Iteration 950: error = 1.2988220, gradient norm = 0.0028786 (50 iterations in 3.311s)
# [t-SNE] Iteration 1000: error = 1.2942867, gradient norm = 0.0025998 (50 iterations in 3.171s)
# [t-SNE] KL divergence after 1000 iterations: 1.294287
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done

# %% [markdown]
# # Prediction Models

# %% [markdown]
# ### Obtaining training and test data

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
print(train.shape, test.shape)
# Out:
# (7352, 564) (2947, 564)

# %%
# get X_train and y_train from csv files
X_train = train.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_train = train.ActivityName

# %%
# get X_test and y_test from test csv file
X_test = test.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_test = test.ActivityName

# %%
print('X_train and y_train : ({},{})'.format(X_train.shape, y_train.shape))
print('X_test  and y_test  : ({},{})'.format(X_test.shape, y_test.shape))
# Out:
# X_train and y_train : ((7352, 561),(7352,))
# X_test  and y_test  : ((2947, 561),(2947,))

# %% [markdown]
# ### Labels that will be used for plotting confusion matrix

# %%
labels=['LAYING', 'SITTING','STANDING','WALKING','WALKING_DOWNSTAIRS','WALKING_UPSTAIRS']

# %% [markdown]
# ### Function to plot confusion matrix

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
plt.rcParams["font.family"] = 'DejaVu Sans'

def plot_confusion_matrix(cm, classes,
                                                normalize=False,
    title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# ### Generic function to run any model specified

# %%
from datetime import datetime
def perform_model(model, X_train, y_train, X_test, y_test, class_labels, cm_normalize=True, \
                 print_cm=True, cm_cmap=plt.cm.Greens):
    
    
    # to store results at various phases
    results = dict()
    
    # time at which model starts training 
    train_start_time = datetime.now()
    print('training the model..')
    model.fit(X_train, y_train)
    print('Done \n \n')
    train_end_time = datetime.now()
    results['training_time'] =  train_end_time - train_start_time
    print('training_time(HH:MM:SS.ms) - {}\n\n'.format(results['training_time']))
    
    
    # predict test data
    print('Predicting test data')
    test_start_time = datetime.now()
    y_pred = model.predict(X_test)
    test_end_time = datetime.now()
    print('Done \n \n')
    results['testing_time'] = test_end_time - test_start_time
    print('testing time(HH:MM:SS:ms) - {}\n\n'.format(results['testing_time']))
    results['predicted'] = y_pred
   

    # calculate overall accuracty of the model
    accuracy = metrics.accuracy_score(y_true=y_test, y_pred=y_pred)
    # store accuracy in results
    results['accuracy'] = accuracy
    print('---------------------')
    print('|      Accuracy      |')
    print('---------------------')
    print('\n    {}\n\n'.format(accuracy))
    
    
    # confusion matrix
    cm = metrics.confusion_matrix(y_test, y_pred)
    results['confusion_matrix'] = cm
    if print_cm: 
        print('--------------------')
        print('| Confusion Matrix |')
        print('--------------------')
        print('\n {}'.format(cm))
        
    # plot confusin matrix
    plt.figure(figsize=(8,8))
    plt.grid(False)
    plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
    plt.show()
    
    # get classification report
    print('-------------------------')
    print('| Classifiction Report |')
    print('-------------------------')
    classification_report = metrics.classification_report(y_test, y_pred)
    # store report in results
    results['classification_report'] = classification_report
    print(classification_report)
    
    # add the trained  model to the results
    results['model'] = model
    
    return results

# %% [markdown]
# ### Method to print the gridsearch Attributes

# %%
def print_grid_search_attributes(model):
    # Estimator that gave highest score among all the estimators formed in GridSearch
    print('--------------------------')
    print('|      Best Estimator     |')
    print('--------------------------')
    print('\n\t{}\n'.format(model.best_estimator_))


    # parameters that gave best results while performing grid search
    print('--------------------------')
    print('|     Best parameters     |')
    print('--------------------------')
    print('\tParameters of best estimator : \n\n\t{}\n'.format(model.best_params_))


    #  number of cross validation splits
    print('---------------------------------')
    print('|   No of CrossValidation sets   |')
    print('--------------------------------')
    print('\n\tTotal numbre of cross validation sets: {}\n'.format(model.n_splits_))


    # Average cross validated score of the best estimator, from the Grid Search 
    print('--------------------------')
    print('|        Best Score       |')
    print('--------------------------')
    print('\n\tAverage Cross Validate scores of best estimator : \n\n\t{}\n'.format(model.best_score_))

# %% [markdown]
# ### 1. Logistic Regression with Grid Search

# %%
from sklearn import linear_model
from sklearn import metrics

from sklearn.model_selection import GridSearchCV

# %%
# start Grid search
parameters = {'C':[0.01, 0.1, 1, 10, 20, 30], 'penalty':['l2','l1']}
log_reg = linear_model.LogisticRegression()
log_reg_grid = GridSearchCV(log_reg, param_grid=parameters, cv=3, verbose=1, n_jobs=-1)
log_reg_grid_results =  perform_model(log_reg_grid, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# training the model..
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# C:\Users\gssp4\anaconda3\envs\myenv2\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 18 fits failed out of a total of 36.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 18 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\gssp4\anaconda3\envs\myenv2\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\gssp4\anaconda3\envs\myenv2\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "C:\Users\gssp4\anaconda3\envs\myenv2\lib\site-packages\sklearn\linear_model\_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Users\gssp4\anaconda3\envs\myenv2\lib\site-packages\sklearn\linear_model\_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\gssp4\anaconda3\envs\myenv2\lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [0.91458247        nan 0.93348876        nan 0.93797756        nan
#  0.93321632        nan 0.93403348        nan 0.93253716        nan]
#   warnings.warn(
# C:\Users\gssp4\anaconda3\envs\myenv2\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:00:14.309820
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.020342
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9592806243637597
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 431  57   0   0   3]
#  [  0  16 516   0   0   0]
#  [  0   0   0 493   2   1]
#  [  0   0   0   4 405  11]
#  [  0   0   0  25   1 445]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.96      0.88      0.92       491
#           STANDING       0.90      0.97      0.93       532
#            WALKING       0.94      0.99      0.97       496
# WALKING_DOWNSTAIRS       0.99      0.96      0.98       420
#   WALKING_UPSTAIRS       0.97      0.94      0.96       471
#
#           accuracy                           0.96      2947
#          macro avg       0.96      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947

# %%
plt.figure(figsize=(8,8))
plt.grid(False)
plot_confusion_matrix(log_reg_grid_results['confusion_matrix'], classes=labels, cmap=plt.cm.Greens, )
plt.show()

# %%
# observe the attributes of the model 
print_grid_search_attributes(log_reg_grid_results['model'])
# Out:
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	LogisticRegression(C=1)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'C': 1, 'penalty': 'l2'}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 3
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9379775574040305

# %% [markdown]
# ### 2. Linear SVC with GridSearch

# %%
from sklearn.svm import LinearSVC

# %%
parameters = {'C':[0.125, 0.5, 1, 2, 8, 16]}
lr_svc = LinearSVC(tol=0.00005)
lr_svc_grid = GridSearchCV(lr_svc, param_grid=parameters, n_jobs=-1, verbose=1)
lr_svc_grid_results = perform_model(lr_svc_grid, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# training the model..
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# C:\Users\gssp4\anaconda3\envs\myenv2\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\gssp4\anaconda3\envs\myenv2\lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:00:42.326544
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.011999
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9667458432304038
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  2 428  58   0   0   3]
#  [  0   9 522   1   0   0]
#  [  0   0   0 496   0   0]
#  [  0   0   0   3 412   5]
#  [  0   0   0  17   0 454]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.98      0.87      0.92       491
#           STANDING       0.90      0.98      0.94       532
#            WALKING       0.96      1.00      0.98       496
# WALKING_DOWNSTAIRS       1.00      0.98      0.99       420
#   WALKING_UPSTAIRS       0.98      0.96      0.97       471
#
#           accuracy                           0.97      2947
#          macro avg       0.97      0.97      0.97      2947
#       weighted avg       0.97      0.97      0.97      2947

# %%
print_grid_search_attributes(lr_svc_grid_results['model'])
# Out:
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	LinearSVC(C=0.5, tol=5e-05)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'C': 0.5}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9422005484722782

# %% [markdown]
# ### 3. Kernel SVM with GridSearch

# %%
from sklearn.svm import SVC
parameters = {'C':[2,8,16],'gamma': [ 0.0078125, 0.125, 2]}
rbf_svm = SVC(kernel='rbf')
rbf_svm_grid = GridSearchCV(rbf_svm,param_grid=parameters, n_jobs=-1)
rbf_svm_grid_results = perform_model(rbf_svm_grid, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# training the model..
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:04:05.255596
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:01.336754
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9626739056667798
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 441  48   0   0   2]
#  [  0  12 520   0   0   0]
#  [  0   0   0 489   2   5]
#  [  0   0   0   4 397  19]
#  [  0   0   0  17   1 453]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.97      0.90      0.93       491
#           STANDING       0.92      0.98      0.95       532
#            WALKING       0.96      0.99      0.97       496
# WALKING_DOWNSTAIRS       0.99      0.95      0.97       420
#   WALKING_UPSTAIRS       0.95      0.96      0.95       471
#
#           accuracy                           0.96      2947
#          macro avg       0.96      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947

# %%
print_grid_search_attributes(rbf_svm_grid_results['model'])
# Out:
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	SVC(C=16, gamma=0.0078125)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'C': 16, 'gamma': 0.0078125}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9447834551903698

# %% [markdown]
# ### 4. Decision Trees with GridSearchCV

# %%
from sklearn.tree import DecisionTreeClassifier
parameters = {'max_depth':np.arange(3,10,2)}
dt = DecisionTreeClassifier()
dt_grid = GridSearchCV(dt,param_grid=parameters, n_jobs=-1)
dt_grid_results = perform_model(dt_grid, X_train, y_train, X_test, y_test, class_labels=labels)
print_grid_search_attributes(dt_grid_results['model'])
# Out:
# training the model..
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:00:33.241062
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.010002
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.8622327790973872
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 386 105   0   0   0]
#  [  0  93 439   0   0   0]
#  [  0   0   0 471  17   8]
#  [  0   0   0  20 339  61]
#  [  0   0   0  78  24 369]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.81      0.79      0.80       491
#           STANDING       0.81      0.83      0.82       532
#            WALKING       0.83      0.95      0.88       496
# WALKING_DOWNSTAIRS       0.89      0.81      0.85       420
#   WALKING_UPSTAIRS       0.84      0.78      0.81       471
#
#           accuracy                           0.86      2947
#          macro avg       0.86      0.86      0.86      2947
#       weighted avg       0.86      0.86      0.86      2947
#
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	DecisionTreeClassifier(max_depth=7)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'max_depth': 7}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.8512045579618659

# %% [markdown]
# ### 5. Random Forest Classifier with GridSearch

# %%
from sklearn.ensemble import RandomForestClassifier
params = {'n_estimators': np.arange(10,100,20), 'max_depth':np.arange(3,15,2)}
rfc = RandomForestClassifier()
rfc_grid = GridSearchCV(rfc, param_grid=params, n_jobs=-1)
rfc_grid_results = perform_model(rfc_grid, X_train, y_train, X_test, y_test, class_labels=labels)
print_grid_search_attributes(rfc_grid_results['model'])
# Out:
# training the model..
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:06:49.715729
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.036003
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9287410926365796
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 436  55   0   0   0]
#  [  0  43 489   0   0   0]
#  [  0   0   0 481   6   9]
#  [  0   0   0  20 360  40]
#  [  0   0   0  31   6 434]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.91      0.89      0.90       491
#           STANDING       0.90      0.92      0.91       532
#            WALKING       0.90      0.97      0.94       496
# WALKING_DOWNSTAIRS       0.97      0.86      0.91       420
#   WALKING_UPSTAIRS       0.90      0.92      0.91       471
#
#           accuracy                           0.93      2947
#          macro avg       0.93      0.93      0.93      2947
#       weighted avg       0.93      0.93      0.93      2947
#
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	RandomForestClassifier(max_depth=11, n_estimators=90)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'max_depth': 11, 'n_estimators': 90}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9201611195123869

# %% [markdown]
# ## Comparing all models

# %%
print('\n                     Accuracy     Error')
print('                     ----------   --------')
print('Logistic Regression : {:.04}%       {:.04}%'.format(log_reg_grid_results['accuracy'] * 100,\
                                                  100-(log_reg_grid_results['accuracy'] * 100)))

print('Linear SVC          : {:.04}%       {:.04}% '.format(lr_svc_grid_results['accuracy'] * 100,\
                                                        100-(lr_svc_grid_results['accuracy'] * 100)))

print('rbf SVM classifier  : {:.04}%      {:.04}% '.format(rbf_svm_grid_results['accuracy'] * 100,\
                                                          100-(rbf_svm_grid_results['accuracy'] * 100)))

print('DecisionTree        : {:.04}%      {:.04}% '.format(dt_grid_results['accuracy'] * 100,\
                                                        100-(dt_grid_results['accuracy'] * 100)))

print('Random Forest       : {:.04}%      {:.04}% '.format(rfc_grid_results['accuracy'] * 100,\
                                                           100-(rfc_grid_results['accuracy'] * 100)))
# Out:
#                      Accuracy     Error
#                      ----------   --------
# Logistic Regression : 95.93%       4.072%
# Linear SVC          : 96.67%       3.325%
# rbf SVM classifier  : 96.27%      3.733%
# DecisionTree        : 86.22%      13.78%
# Random Forest       : 92.87%      7.126%
